# %%
import pandas as pd
import numpy as np
from IPython.display import display
from itertools import combinations
from scipy.stats import kstest, spearmanr, pearsonr

# %%
pd.set_option('display.max_columns', None)

# %%
df = pd.read_csv("HR RAW DATA.csv")
df.sample(2)
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate Department  \
# 1223        1223  32        No            NaN   1146,0$        NaN
# 1450        1450  28        No  travel_rarely   1172,0$     Sales
#
#       DistanceFromHome  Education EducationField  employeecount  \
# 1223                15          4            NaN              1
# 1450                 3          3        Medical              1
#
#      employeenumber  EnvironmentSatisfaction  Gender     HourlyRate  \
# 1223            NaN                        3       1  Not Available
# 1450         1875,0                        2       1             78
#
#       JobInvolvement  JobLevel                      JobRole  JobSatisfaction  \
# 1223               3         2   HeaLTHcare RePrESENtATIVe                 4
# 1450               3         1        SaLes REPREseNtATive                 2
#
#      MaritalStatus MonthlyIncome  MonthlyRate  NUMCOMPANIESWORKED Over18  \
# ...

# %%
df[['JobRoleNew', 'DepartmentNew']] = df['RoleDepartament'].str.split(' - ', expand=True)
df.head(5)
# Out:
#    Unnamed: 0 Age Attrition BusinessTravel DailyRate  \
# 0           0  51        No            NaN    684,0$
# 1           1  52        No            NaN    699,0$
# 2           2  42        No  travel_rarely    532,0$
# 3           3  47        No  travel_rarely    359,0$
# 4           4  46        No            NaN   1319,0$
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 0                       NaN                 6          3               NaN
# 1                       NaN                 1          4     Life Sciences
# 2   Research & Development                  4          2  Technical Degree
# 3                       NaN                 2          4           Medical
# 4                       NaN                 3          3  Technical Degree
#
#    employeecount employeenumber  EnvironmentSatisfaction  Gender HourlyRate  \
# 0              1          162,0                        1       0         51
# ...

# %%
df['ComparisonDepartment'] = df['DepartmentNew'] == df['Department']

# %%
df['ComparisionJobRole'] = df ['JobRoleNew'] == df ['JobRole']

# %%
df.head(10)
# Out:
#    Unnamed: 0 Age Attrition     BusinessTravel DailyRate  \
# 0           0  51        No                NaN    684,0$
# 1           1  52        No                NaN    699,0$
# 2           2  42        No      travel_rarely    532,0$
# 3           3  47        No      travel_rarely    359,0$
# 4           4  46        No                NaN   1319,0$
# 5           5  48        No                NaN    117,0$
# 6           6  59        No                NaN   1435,0$
# 7           7  42        No      travel_rarely    635,0$
# 8           8  41        No                NaN   1276,0$
# 9           9  41        No  travel_frequently    840,0$
#
#                  Department  DistanceFromHome  Education    EducationField  \
# 0                       NaN                 6          3               NaN
# 1                       NaN                 1          4     Life Sciences
# 2   Research & Development                  4          2  Technical Degree
# ...

# %%
df[["JobRoleNew", "Department", "JobRole", "DepartmentNew", "RoleDepartament"]].head()
# Out:
#    JobRoleNew  Department  JobRole  DepartmentNew  RoleDepartament
# 0        True        True    False           True             True
# 1        True        True    False           True             True
# 2       False       False    False          False            False
# 3        True        True    False           True             True
# 4        True        True    False           True             True

# %%
df["RoleDepartament"].value_counts().sum()
# Out:
# 302

# %%
df["JobRoleNew"].value_counts().sum()
# Out:
# 302

# %%
df["Department"].value_counts().sum()
# Out:
# 302

# %%
df["JobRole"].value_counts().sum()
# Out:
# 1614

# %%
df["DepartmentNew"].value_counts().sum()
# Out:
# 302

# %%
mismatched_rows_department = df[df['DepartmentNew'] != df['Department']]
print(mismatched_rows_department)
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate Department  \
# 0              0  51        No            NaN    684,0$        NaN
# 1              1  52        No            NaN    699,0$        NaN
# 3              3  47        No  travel_rarely    359,0$        NaN
# 4              4  46        No            NaN   1319,0$        NaN
# 6              6  59        No            NaN   1435,0$        NaN
# ...          ...  ..       ...            ...       ...        ...
# 1609        1609  36       Yes  travel_rarely    530,0$        NaN
# 1610        1610  45        No     non-travel    805,0$        NaN
# 1611        1611  39        No  travel_rarely    903,0$        NaN
# 1612        1612  36        No     non-travel   1229,0$        NaN
# 1613        1613  46        No            NaN    566,0$        NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# 0                    6          3               NaN              1
# ...

# %%
mismatched_rows_JobRole = df[df['JobRoleNew'] != df['JobRole']]
print(mismatched_rows_JobRole)
# Out:
#       Unnamed: 0 Age Attrition BusinessTravel DailyRate Department  \
# 0              0  51        No            NaN    684,0$        NaN
# 1              1  52        No            NaN    699,0$        NaN
# 3              3  47        No  travel_rarely    359,0$        NaN
# 4              4  46        No            NaN   1319,0$        NaN
# 6              6  59        No            NaN   1435,0$        NaN
# ...          ...  ..       ...            ...       ...        ...
# 1609        1609  36       Yes  travel_rarely    530,0$        NaN
# 1610        1610  45        No     non-travel    805,0$        NaN
# 1611        1611  39        No  travel_rarely    903,0$        NaN
# 1612        1612  36        No     non-travel   1229,0$        NaN
# 1613        1613  46        No            NaN    566,0$        NaN
#
#       DistanceFromHome  Education    EducationField  employeecount  \
# 0                    6          3               NaN              1
# ...

# %%
# Mostrar los índices de las filas que no coinciden
print("\nÍndices de las filas que no coinciden en Departament:")
print(mismatched_rows_department.index.tolist())
# Out:
# Índices de las filas que no coinciden en Departament:
# ...

# %%
# Mostrar los índices de las filas que no coinciden
print("\nÍndices de las filas que no coincidenen JobRole:")
print(mismatched_rows_JobRole.index.tolist())
# Out:
# Índices de las filas que no coincidenen JobRole:
# ...

# %%
df_limpio = pd.read_csv("hr_raw_data_limpio_.csv")
df_limpio.head()
# Out:
#    Unnamed: 0  Age Attrition BusinessTravel  DailyRate  \
# 0           0   51        No            NaN      684.0
# 1           1   52        No            NaN      699.0
# 2           2   42        No  Travel Rarely      532.0
# 3           3   47        No  Travel Rarely      359.0
# 4           4   46        No            NaN     1319.0
#
#                  Department  DistanceFromHome    Education    EducationField  \
# 0                       NaN                 6  High School               NaN
# 1                       NaN                 1   Bachelor's     Life Sciences
# 2   Research & Development                  4    Secondary  Technical Degree
# 3                       NaN                 2   Bachelor's           Medical
# 4                       NaN                 3  High School  Technical Degree
#
#    EmployeeNumber EnvironmentSatisfaction  Gender  HourlyRate JobInvolvement  \
# 0           162.0                Very Low    Male        51.0         Medium
# ...

# %%
df_limpio[['JobRoleNew', 'DepartmentNew']] = df_limpio['RoleDepartament'].str.strip().str.split(' ', n = 1, expand=True)
df_limpio.head(5)
# Out:
#    Unnamed: 0  Age Attrition BusinessTravel  DailyRate  \
# 0           0   51        No            NaN      684.0
# 1           1   52        No            NaN      699.0
# 2           2   42        No  Travel Rarely      532.0
# 3           3   47        No  Travel Rarely      359.0
# 4           4   46        No            NaN     1319.0
#
#                  Department  DistanceFromHome    Education    EducationField  \
# 0                       NaN                 6  High School               NaN
# 1                       NaN                 1   Bachelor's     Life Sciences
# 2   Research & Development                  4    Secondary  Technical Degree
# 3                       NaN                 2   Bachelor's           Medical
# 4                       NaN                 3  High School  Technical Degree
#
#    EmployeeNumber EnvironmentSatisfaction  Gender  HourlyRate JobInvolvement  \
# 0           162.0                Very Low    Male        51.0         Medium
# ...
